# %% [markdown]
# # BEAUTIFUL SOUP

# %% [markdown]
# pip install bs4

# %% [markdown]
# pip install beautifulsoup4

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url="https://www.flipkart.com/search?q=laptop&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=off&as=off"

# %%
response= requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(response.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
name=soup.select("._4rR01T")

# %%
name
# Out:
# [<div class="_4rR01T">HP Celeron Dual Core - (4 GB/128 GB EMMC Storage/Chrome OS) 15a- na0008TU Chromebook</div>,
#  <div class="_4rR01T">HP Chromebook x360 Intel Celeron Quad Core - (4 GB/64 GB EMMC Storage/Chrome OS) 14a-ca0504TU Chromebo...</div>,
#  <div class="_4rR01T">ASUS Vivobook 15 Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) X515EA-EJ322WS | X515EA-EJ328WS ...</div>,
#  <div class="_4rR01T">ASUS Vivobook 15 Core i5 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) X515EA-EJ522WS Thin and Light La...</div>,
#  <div class="_4rR01T">Lenovo IdeaPad Slim 3 Intel Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) 81X800J3IN|81X800LGIN...</div>,
#  <div class="_4rR01T">ASUS Vivobook Go 15 Celeron Dual Core - (4 GB/256 GB SSD/Windows 11 Home) E510MA-EJ001W Thin and Light...</div>,
#  <div class="_4rR01T">HP 15s (2023) Intel Core i5 11th Gen - (16 GB/512 GB SSD/Windows 11 Home) 15s-fr4001TU Thin and Light ...</div>,
# ...

# %%
price=soup.select("._1_WHN1")

# %%
price
# Out:
# [<div class="_30jeq3 _1_WHN1">₹18,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹18,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹37,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹47,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹38,190</div>,
#  <div class="_30jeq3 _1_WHN1">₹25,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹55,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹19,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹42,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹36,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹13,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹13,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹30,790</div>,
#  <div class="_30jeq3 _1_WHN1">₹43,490</div>,
#  <div class="_30jeq3 _1_WHN1">₹49,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹35,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹14,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹49,490</div>,
#  <div class="_30jeq3 _1_WHN1">₹30,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹28,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹45,490</div>,
# ...

# %%
detail=soup.select("._3tbKJL span")

# %%
detail
# Out:
# [<span>43% off</span>,
#  <span>39% off</span>,
#  <span>24% off</span>,
#  <span>32% off</span>,
#  <span>39% off</span>,
#  <span>23% off</span>,
#  <span>5% off</span>,
#  <span>21% off</span>,
#  <span>16% off</span>,
#  <span>32% off</span>,
#  <span>44% off</span>,
#  <span>44% off</span>,
#  <span>33% off</span>,
#  <span>12% off</span>,
#  <span>23% off</span>,
#  <span>48% off</span>,
#  <span>46% off</span>,
#  <span>42% off</span>,
#  <span>31% off</span>,
#  <span>24% off</span>,
#  <span>33% off</span>,
#  <span>41% off</span>,
#  <span>22% off</span>,
#  <span>30% off</span>]

# %%
import pandas

# %%
laptop = pandas.DataFrame(name,columns=["laptop"])

# %%
laptop
# Out:
#                                                laptop
# 0   HP Celeron Dual Core - (4 GB/128 GB EMMC Stora...
# 1   HP Chromebook x360 Intel Celeron Quad Core - (...
# 2   ASUS Vivobook 15 Core i3 11th Gen - (8 GB/512 ...
# 3   ASUS Vivobook 15 Core i5 11th Gen - (8 GB/512 ...
# 4   Lenovo IdeaPad Slim 3 Intel Core i3 11th Gen -...
# 5   ASUS Vivobook Go 15 Celeron Dual Core - (4 GB/...
# 6   HP 15s (2023) Intel Core i5 11th Gen - (16 GB/...
# 7   HP Chromebook MediaTek Kompanio 500 - (4 GB/64...
# 8   HP 15s (2023) Intel Core i3 12th Gen - (8 GB/5...
# 9   realme Book (Slim) Core i3 11th Gen - (8 GB/25...
# 10  ASUS Chromebook Celeron Dual Core - (4 GB/64 G...
# 11  Primebook 4G Android Based MediaTek MT8788 - (...
# 12  Lenovo Intel Celeron Dual Core - (8 GB/256 GB ...
# 13  HP Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/...
# 14  MSI Core i5 12th Gen - (16 GB/512 GB SSD/Windo...
# 15  Lenovo V15 Ryzen 5 Hexa Core 5500U - (8 GB/512...
# ...

# %%
laptop["price"]=price

# %%
laptop
# Out:
#                                                laptop      price
# 0   HP Celeron Dual Core - (4 GB/128 GB EMMC Stora...  [₹18,990]
# 1   HP Chromebook x360 Intel Celeron Quad Core - (...  [₹18,990]
# 2   ASUS Vivobook 15 Core i3 11th Gen - (8 GB/512 ...  [₹37,990]
# 3   ASUS Vivobook 15 Core i5 11th Gen - (8 GB/512 ...  [₹47,990]
# 4   Lenovo IdeaPad Slim 3 Intel Core i3 11th Gen -...  [₹38,190]
# 5   ASUS Vivobook Go 15 Celeron Dual Core - (4 GB/...  [₹25,990]
# 6   HP 15s (2023) Intel Core i5 11th Gen - (16 GB/...  [₹55,990]
# 7   HP Chromebook MediaTek Kompanio 500 - (4 GB/64...  [₹19,990]
# 8   HP 15s (2023) Intel Core i3 12th Gen - (8 GB/5...  [₹42,990]
# 9   realme Book (Slim) Core i3 11th Gen - (8 GB/25...  [₹36,999]
# 10  ASUS Chromebook Celeron Dual Core - (4 GB/64 G...  [₹13,990]
# 11  Primebook 4G Android Based MediaTek MT8788 - (...  [₹13,990]
# 12  Lenovo Intel Celeron Dual Core - (8 GB/256 GB ...  [₹30,790]
# ...

# %%
laptop["discount"]=detail

# %%
laptop
# Out:
#                                                laptop      price   discount
# 0   HP Celeron Dual Core - (4 GB/128 GB EMMC Stora...  [₹18,990]  [43% off]
# 1   HP Chromebook x360 Intel Celeron Quad Core - (...  [₹18,990]  [39% off]
# 2   ASUS Vivobook 15 Core i3 11th Gen - (8 GB/512 ...  [₹37,990]  [24% off]
# 3   ASUS Vivobook 15 Core i5 11th Gen - (8 GB/512 ...  [₹47,990]  [32% off]
# 4   Lenovo IdeaPad Slim 3 Intel Core i3 11th Gen -...  [₹38,190]  [39% off]
# 5   ASUS Vivobook Go 15 Celeron Dual Core - (4 GB/...  [₹25,990]  [23% off]
# 6   HP 15s (2023) Intel Core i5 11th Gen - (16 GB/...  [₹55,990]   [5% off]
# 7   HP Chromebook MediaTek Kompanio 500 - (4 GB/64...  [₹19,990]  [21% off]
# 8   HP 15s (2023) Intel Core i3 12th Gen - (8 GB/5...  [₹42,990]  [16% off]
# 9   realme Book (Slim) Core i3 11th Gen - (8 GB/25...  [₹36,999]  [32% off]
# 10  ASUS Chromebook Celeron Dual Core - (4 GB/64 G...  [₹13,990]  [44% off]
# ...

# %%
print(laptop)
# Out:
#                                                laptop      price   discount
# 0   HP Celeron Dual Core - (4 GB/128 GB EMMC Stora...  [₹18,990]  [43% off]
# 1   HP Chromebook x360 Intel Celeron Quad Core - (...  [₹18,990]  [39% off]
# 2   ASUS Vivobook 15 Core i3 11th Gen - (8 GB/512 ...  [₹37,990]  [24% off]
# 3   ASUS Vivobook 15 Core i5 11th Gen - (8 GB/512 ...  [₹47,990]  [32% off]
# 4   Lenovo IdeaPad Slim 3 Intel Core i3 11th Gen -...  [₹38,190]  [39% off]
# 5   ASUS Vivobook Go 15 Celeron Dual Core - (4 GB/...  [₹25,990]  [23% off]
# 6   HP 15s (2023) Intel Core i5 11th Gen - (16 GB/...  [₹55,990]   [5% off]
# 7   HP Chromebook MediaTek Kompanio 500 - (4 GB/64...  [₹19,990]  [21% off]
# 8   HP 15s (2023) Intel Core i3 12th Gen - (8 GB/5...  [₹42,990]  [16% off]
# 9   realme Book (Slim) Core i3 11th Gen - (8 GB/25...  [₹36,999]  [32% off]
# 10  ASUS Chromebook Celeron Dual Core - (4 GB/64 G...  [₹13,990]  [44% off]
# ...

# %%
va=soup.select(".fMghEO")

# %%
va
# Out:
# [<div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">Intel Celeron Dual Core Processor</li><li class="rgWa7D">4 GB LPDDR4X RAM</li><li class="rgWa7D">Chrome Operating System</li><li class="rgWa7D">39.62 cm (15.6 Inch) Display</li><li class="rgWa7D">1 Year Onsite Warranty</li></ul></div>,
#  <div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">Intel Celeron Quad Core Processor</li><li class="rgWa7D">4 GB LPDDR4 RAM</li><li class="rgWa7D">64 bit Chrome Operating System</li><li class="rgWa7D">35.56 cm (14 Inch) Touchscreen Display</li><li class="rgWa7D">1 Year Onsite warranty</li></ul></div>,
#  <div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">Intel Core i3 Processor (11th Gen)</li><li class="rgWa7D">8 GB DDR4 RAM</li><li class="rgWa7D">64 bit Windows 11 Operating System</li><li class="rgWa7D">512 GB SSD</li><li class="rgWa7D">39.62 cm (15.6 Inch) Display</li><li class="rgWa7D">1 Year Onsite Warranty</li></ul></div>,
# ...

# %%
laptop["va"]=va

# %%
laptop
# Out:
#                                                laptop      price   discount  \
# 0   HP Celeron Dual Core - (4 GB/128 GB EMMC Stora...  [₹18,990]  [43% off]
# 1   HP Chromebook x360 Intel Celeron Quad Core - (...  [₹18,990]  [39% off]
# 2   ASUS Vivobook 15 Core i3 11th Gen - (8 GB/512 ...  [₹37,990]  [24% off]
# 3   ASUS Vivobook 15 Core i5 11th Gen - (8 GB/512 ...  [₹47,990]  [32% off]
# 4   Lenovo IdeaPad Slim 3 Intel Core i3 11th Gen -...  [₹38,190]  [39% off]
# 5   ASUS Vivobook Go 15 Celeron Dual Core - (4 GB/...  [₹25,990]  [23% off]
# 6   HP 15s (2023) Intel Core i5 11th Gen - (16 GB/...  [₹55,990]   [5% off]
# 7   HP Chromebook MediaTek Kompanio 500 - (4 GB/64...  [₹19,990]  [21% off]
# 8   HP 15s (2023) Intel Core i3 12th Gen - (8 GB/5...  [₹42,990]  [16% off]
# 9   realme Book (Slim) Core i3 11th Gen - (8 GB/25...  [₹36,999]  [32% off]
# 10  ASUS Chromebook Celeron Dual Core - (4 GB/64 G...  [₹13,990]  [44% off]
# ...

# %%
laptop.to_csv("C:/Users/HP/Documents/nm/r.csv")

# %%
d=pandas.read_csv("C:/Users/HP/Documents/nm/r.csv")

# %%
d
# Out:
#     Unnamed: 0                                             laptop    price  \
# 0            0  HP Celeron Dual Core - (4 GB/128 GB EMMC Stora...   ₹18,99
# 1            1  HP Chromebook x360 Intel Celeron Quad Core - (...   ₹18,99
# 2            2  ASUS Vivobook 15 Core i3 11th Gen - (8 GB/512 ...   ₹37,99
# 3            3  ASUS Vivobook 15 Core i5 11th Gen - (8 GB/512 ...   ₹47,99
# 4            4  Lenovo IdeaPad Slim 3 Intel Core i3 11th Gen -...   ₹38,19
# 5            5  ASUS Vivobook Go 15 Celeron Dual Core - (4 GB/...   ₹25,99
# 6            6  HP 15s (2023) Intel Core i5 11th Gen - (16 GB/...   ₹55,99
# 7            7  HP Chromebook MediaTek Kompanio 500 - (4 GB/64...   ₹19,99
# 8            8  HP 15s (2023) Intel Core i3 12th Gen - (8 GB/5...   ₹42,99
# 9            9  realme Book (Slim) Core i3 11th Gen - (8 GB/25...  ₹36,999
# 10          10  ASUS Chromebook Celeron Dual Core - (4 GB/64 G...   ₹13,99
# ...

# %%
c1=d["price"]

# %%
c1
# Out:
# 0     <div class="_30jeq3 _1_WHN1">₹18,990</div>
# 1     <div class="_30jeq3 _1_WHN1">₹18,990</div>
# 2     <div class="_30jeq3 _1_WHN1">₹37,990</div>
# 3     <div class="_30jeq3 _1_WHN1">₹47,990</div>
# 4     <div class="_30jeq3 _1_WHN1">₹38,190</div>
# 5     <div class="_30jeq3 _1_WHN1">₹25,990</div>
# 6     <div class="_30jeq3 _1_WHN1">₹55,990</div>
# 7     <div class="_30jeq3 _1_WHN1">₹19,990</div>
# 8     <div class="_30jeq3 _1_WHN1">₹42,990</div>
# 9     <div class="_30jeq3 _1_WHN1">₹36,999</div>
# 10    <div class="_30jeq3 _1_WHN1">₹13,990</div>
# 11    <div class="_30jeq3 _1_WHN1">₹13,990</div>
# 12    <div class="_30jeq3 _1_WHN1">₹30,790</div>
# 13    <div class="_30jeq3 _1_WHN1">₹43,490</div>
# 14    <div class="_30jeq3 _1_WHN1">₹49,990</div>
# 15    <div class="_30jeq3 _1_WHN1">₹35,990</div>
# 16    <div class="_30jeq3 _1_WHN1">₹14,990</div>
# 17    <div class="_30jeq3 _1_WHN1">₹49,490</div>
# 18    <div class="_30jeq3 _1_WHN1">₹30,990</div>
# ...

# %%
t=c1.str.strip("</div>").astype(str)

# %%
t
# Out:
# 0      class="_30jeq3 _1_WHN1">₹18,990
# 1      class="_30jeq3 _1_WHN1">₹18,990
# 2      class="_30jeq3 _1_WHN1">₹37,990
# 3      class="_30jeq3 _1_WHN1">₹47,990
# 4      class="_30jeq3 _1_WHN1">₹38,190
# 5      class="_30jeq3 _1_WHN1">₹25,990
# 6      class="_30jeq3 _1_WHN1">₹55,990
# 7      class="_30jeq3 _1_WHN1">₹19,990
# 8      class="_30jeq3 _1_WHN1">₹42,990
# 9      class="_30jeq3 _1_WHN1">₹36,999
# 10     class="_30jeq3 _1_WHN1">₹13,990
# 11     class="_30jeq3 _1_WHN1">₹13,990
# 12     class="_30jeq3 _1_WHN1">₹30,790
# 13     class="_30jeq3 _1_WHN1">₹43,490
# 14     class="_30jeq3 _1_WHN1">₹49,990
# 15     class="_30jeq3 _1_WHN1">₹35,990
# 16     class="_30jeq3 _1_WHN1">₹14,990
# 17     class="_30jeq3 _1_WHN1">₹49,490
# 18     class="_30jeq3 _1_WHN1">₹30,990
# 19     class="_30jeq3 _1_WHN1">₹28,990
# 20     class="_30jeq3 _1_WHN1">₹45,490
# 21     class="_30jeq3 _1_WHN1">₹18,990
# 22     class="_30jeq3 _1_WHN1">₹34,990
# 23     class="_30jeq3 _1_WHN1">₹20,990
# ...

# %%
correct1=t.str.strip('class="_30jeq3 _1_WHN1">').astype(str)

# %%
correct1
# Out:
# 0      ₹18,99
# 1      ₹18,99
# 2      ₹37,99
# 3      ₹47,99
# 4      ₹38,19
# 5      ₹25,99
# 6      ₹55,99
# 7      ₹19,99
# 8      ₹42,99
# 9     ₹36,999
# 10     ₹13,99
# 11     ₹13,99
# 12     ₹30,79
# 13     ₹43,49
# 14     ₹49,99
# 15     ₹35,99
# 16     ₹14,99
# 17     ₹49,49
# 18     ₹30,99
# 19     ₹28,99
# 20     ₹45,49
# 21     ₹18,99
# 22     ₹34,99
# 23     ₹20,99
# Name: price, dtype: object

# %%
c2=d["discount"]
c2
# Out:
# 0     <span>43% off</span>
# 1     <span>39% off</span>
# 2     <span>24% off</span>
# 3     <span>32% off</span>
# 4     <span>39% off</span>
# 5     <span>23% off</span>
# 6      <span>5% off</span>
# 7     <span>21% off</span>
# 8     <span>16% off</span>
# 9     <span>32% off</span>
# 10    <span>44% off</span>
# 11    <span>44% off</span>
# 12    <span>33% off</span>
# 13    <span>12% off</span>
# 14    <span>23% off</span>
# 15    <span>48% off</span>
# 16    <span>46% off</span>
# 17    <span>42% off</span>
# 18    <span>31% off</span>
# 19    <span>24% off</span>
# 20    <span>33% off</span>
# 21    <span>41% off</span>
# 22    <span>22% off</span>
# 23    <span>30% off</span>
# Name: discount, dtype: object

# %%
t=c2.str.strip("</span>").astype(str)

# %%
t
# Out:
# 0     43% off
# 1     39% off
# 2     24% off
# 3     32% off
# 4     39% off
# 5     23% off
# 6      5% off
# 7     21% off
# 8     16% off
# 9     32% off
# 10    44% off
# 11    44% off
# 12    33% off
# 13    12% off
# 14    23% off
# 15    48% off
# 16    46% off
# 17    42% off
# 18    31% off
# 19    24% off
# 20    33% off
# 21    41% off
# 22    22% off
# 23    30% off
# Name: discount, dtype: object

# %%
laptop["price"]=correct1

# %%
laptop
# Out:
#                                                laptop    price   discount  \
# 0   HP Celeron Dual Core - (4 GB/128 GB EMMC Stora...   ₹18,99  [43% off]
# 1   HP Chromebook x360 Intel Celeron Quad Core - (...   ₹18,99  [39% off]
# 2   ASUS Vivobook 15 Core i3 11th Gen - (8 GB/512 ...   ₹37,99  [24% off]
# 3   ASUS Vivobook 15 Core i5 11th Gen - (8 GB/512 ...   ₹47,99  [32% off]
# 4   Lenovo IdeaPad Slim 3 Intel Core i3 11th Gen -...   ₹38,19  [39% off]
# 5   ASUS Vivobook Go 15 Celeron Dual Core - (4 GB/...   ₹25,99  [23% off]
# 6   HP 15s (2023) Intel Core i5 11th Gen - (16 GB/...   ₹55,99   [5% off]
# 7   HP Chromebook MediaTek Kompanio 500 - (4 GB/64...   ₹19,99  [21% off]
# 8   HP 15s (2023) Intel Core i3 12th Gen - (8 GB/5...   ₹42,99  [16% off]
# 9   realme Book (Slim) Core i3 11th Gen - (8 GB/25...  ₹36,999  [32% off]
# 10  ASUS Chromebook Celeron Dual Core - (4 GB/64 G...   ₹13,99  [44% off]
# 11  Primebook 4G Android Based MediaTek MT8788 - (...   ₹13,99  [44% off]
# ...

# %%
laptop["discount"]=t

# %% [markdown]
# laptop.drop["va"]

# %%
print(laptop)
# Out:
#                                                laptop    price discount  \
# 0   HP Celeron Dual Core - (4 GB/128 GB EMMC Stora...   ₹18,99  43% off
# 1   HP Chromebook x360 Intel Celeron Quad Core - (...   ₹18,99  39% off
# 2   ASUS Vivobook 15 Core i3 11th Gen - (8 GB/512 ...   ₹37,99  24% off
# 3   ASUS Vivobook 15 Core i5 11th Gen - (8 GB/512 ...   ₹47,99  32% off
# 4   Lenovo IdeaPad Slim 3 Intel Core i3 11th Gen -...   ₹38,19  39% off
# 5   ASUS Vivobook Go 15 Celeron Dual Core - (4 GB/...   ₹25,99  23% off
# 6   HP 15s (2023) Intel Core i5 11th Gen - (16 GB/...   ₹55,99   5% off
# 7   HP Chromebook MediaTek Kompanio 500 - (4 GB/64...   ₹19,99  21% off
# 8   HP 15s (2023) Intel Core i3 12th Gen - (8 GB/5...   ₹42,99  16% off
# 9   realme Book (Slim) Core i3 11th Gen - (8 GB/25...  ₹36,999  32% off
# 10  ASUS Chromebook Celeron Dual Core - (4 GB/64 G...   ₹13,99  44% off
# 11  Primebook 4G Android Based MediaTek MT8788 - (...   ₹13,99  44% off
# ...

# %%
c3=d["va"]
c3
# Out:
# 0     <div class="fMghEO"><ul class="_1xgFaf"><li cl...
# 1     <div class="fMghEO"><ul class="_1xgFaf"><li cl...
# 2     <div class="fMghEO"><ul class="_1xgFaf"><li cl...
# 3     <div class="fMghEO"><ul class="_1xgFaf"><li cl...
# 4     <div class="fMghEO"><ul class="_1xgFaf"><li cl...
# 5     <div class="fMghEO"><ul class="_1xgFaf"><li cl...
# 6     <div class="fMghEO"><ul class="_1xgFaf"><li cl...
# 7     <div class="fMghEO"><ul class="_1xgFaf"><li cl...
# 8     <div class="fMghEO"><ul class="_1xgFaf"><li cl...
# 9     <div class="fMghEO"><ul class="_1xgFaf"><li cl...
# 10    <div class="fMghEO"><ul class="_1xgFaf"><li cl...
# 11    <div class="fMghEO"><ul class="_1xgFaf"><li cl...
# 12    <div class="fMghEO"><ul class="_1xgFaf"><li cl...
# 13    <div class="fMghEO"><ul class="_1xgFaf"><li cl...
# 14    <div class="fMghEO"><ul class="_1xgFaf"><li cl...
# 15    <div class="fMghEO"><ul class="_1xgFaf"><li cl...
# 16    <div class="fMghEO"><ul class="_1xgFaf"><li cl...
# ...

# %%
b=c3.str.strip('<div class="fMghEO">ul class="_1xgFaf"><li class="rgWa7D"></li><li').astype(str)

# %%
b
# Out:
# 0     Intel Celeron Dual Core Processor</li><li clas...
# 1     Intel Celeron Quad Core Processor</li><li clas...
# 2     Intel Core i3 Processor (11th Gen)</li><li cla...
# 3     Intel Core i5 Processor (11th Gen)</li><li cla...
# 4     Intel Core i3 Processor (11th Gen)</li><li cla...
# 5     Intel Celeron Dual Core Processor</li><li clas...
# 6     Intel Core i5 Processor (11th Gen)</li><li cla...
# 7     ediaTek MediaTek Kompanio 500 Processor</li><l...
# 8     Intel Core i3 Processor (12th Gen)</li><li cla...
# 9     Stylish &amp; Portable Thin and Light Laptop</...
# 10    Intel Celeron Dual Core Processor</li><li clas...
# 11    ediaTek MediaTek MT8788 Processor</li><li clas...
# 12    Intel Celeron Dual Core Processor</li><li clas...
# 13    AMD Ryzen 5 Hexa Core Processor</li><li class=...
# 14    Intel Core i5 Processor (12th Gen)</li><li cla...
# 15    AMD Ryzen 5 Hexa Core Processor</li><li class=...
# 16    ediaTek MediaTek MT8788 Processor</li><li clas...
# ...

# %%
laptop["va"]=b

# %%
laptop
# Out:
#                                                laptop    price discount  \
# 0   HP Celeron Dual Core - (4 GB/128 GB EMMC Stora...   ₹18,99  43% off
# 1   HP Chromebook x360 Intel Celeron Quad Core - (...   ₹18,99  39% off
# 2   ASUS Vivobook 15 Core i3 11th Gen - (8 GB/512 ...   ₹37,99  24% off
# 3   ASUS Vivobook 15 Core i5 11th Gen - (8 GB/512 ...   ₹47,99  32% off
# 4   Lenovo IdeaPad Slim 3 Intel Core i3 11th Gen -...   ₹38,19  39% off
# 5   ASUS Vivobook Go 15 Celeron Dual Core - (4 GB/...   ₹25,99  23% off
# 6   HP 15s (2023) Intel Core i5 11th Gen - (16 GB/...   ₹55,99   5% off
# 7   HP Chromebook MediaTek Kompanio 500 - (4 GB/64...   ₹19,99  21% off
# 8   HP 15s (2023) Intel Core i3 12th Gen - (8 GB/5...   ₹42,99  16% off
# 9   realme Book (Slim) Core i3 11th Gen - (8 GB/25...  ₹36,999  32% off
# 10  ASUS Chromebook Celeron Dual Core - (4 GB/64 G...   ₹13,99  44% off
# 11  Primebook 4G Android Based MediaTek MT8788 - (...   ₹13,99  44% off
# ...

# %%
d
# Out:
#     Unnamed: 0                                             laptop    price  \
# 0            0  HP Celeron Dual Core - (4 GB/128 GB EMMC Stora...   ₹18,99
# 1            1  HP Chromebook x360 Intel Celeron Quad Core - (...   ₹18,99
# 2            2  ASUS Vivobook 15 Core i3 11th Gen - (8 GB/512 ...   ₹37,99
# 3            3  ASUS Vivobook 15 Core i5 11th Gen - (8 GB/512 ...   ₹47,99
# 4            4  Lenovo IdeaPad Slim 3 Intel Core i3 11th Gen -...   ₹38,19
# 5            5  ASUS Vivobook Go 15 Celeron Dual Core - (4 GB/...   ₹25,99
# 6            6  HP 15s (2023) Intel Core i5 11th Gen - (16 GB/...   ₹55,99
# 7            7  HP Chromebook MediaTek Kompanio 500 - (4 GB/64...   ₹19,99
# 8            8  HP 15s (2023) Intel Core i3 12th Gen - (8 GB/5...   ₹42,99
# 9            9  realme Book (Slim) Core i3 11th Gen - (8 GB/25...  ₹36,999
# 10          10  ASUS Chromebook Celeron Dual Core - (4 GB/64 G...   ₹13,99
# ...

# %%
laptop=laptop.drop("va",axis=1)

# %%
laptop
# Out:
#                                                laptop    price discount
# 0   HP Celeron Dual Core - (4 GB/128 GB EMMC Stora...   ₹18,99  43% off
# 1   HP Chromebook x360 Intel Celeron Quad Core - (...   ₹18,99  39% off
# 2   ASUS Vivobook 15 Core i3 11th Gen - (8 GB/512 ...   ₹37,99  24% off
# 3   ASUS Vivobook 15 Core i5 11th Gen - (8 GB/512 ...   ₹47,99  32% off
# 4   Lenovo IdeaPad Slim 3 Intel Core i3 11th Gen -...   ₹38,19  39% off
# 5   ASUS Vivobook Go 15 Celeron Dual Core - (4 GB/...   ₹25,99  23% off
# 6   HP 15s (2023) Intel Core i5 11th Gen - (16 GB/...   ₹55,99   5% off
# 7   HP Chromebook MediaTek Kompanio 500 - (4 GB/64...   ₹19,99  21% off
# 8   HP 15s (2023) Intel Core i3 12th Gen - (8 GB/5...   ₹42,99  16% off
# 9   realme Book (Slim) Core i3 11th Gen - (8 GB/25...  ₹36,999  32% off
# 10  ASUS Chromebook Celeron Dual Core - (4 GB/64 G...   ₹13,99  44% off
# 11  Primebook 4G Android Based MediaTek MT8788 - (...   ₹13,99  44% off
# ...

# %%
laptop
# Out:
#                                                laptop    price discount
# 0   HP Celeron Dual Core - (4 GB/128 GB EMMC Stora...   ₹18,99  43% off
# 1   HP Chromebook x360 Intel Celeron Quad Core - (...   ₹18,99  39% off
# 2   ASUS Vivobook 15 Core i3 11th Gen - (8 GB/512 ...   ₹37,99  24% off
# 3   ASUS Vivobook 15 Core i5 11th Gen - (8 GB/512 ...   ₹47,99  32% off
# 4   Lenovo IdeaPad Slim 3 Intel Core i3 11th Gen -...   ₹38,19  39% off
# 5   ASUS Vivobook Go 15 Celeron Dual Core - (4 GB/...   ₹25,99  23% off
# 6   HP 15s (2023) Intel Core i5 11th Gen - (16 GB/...   ₹55,99   5% off
# 7   HP Chromebook MediaTek Kompanio 500 - (4 GB/64...   ₹19,99  21% off
# 8   HP 15s (2023) Intel Core i3 12th Gen - (8 GB/5...   ₹42,99  16% off
# 9   realme Book (Slim) Core i3 11th Gen - (8 GB/25...  ₹36,999  32% off
# 10  ASUS Chromebook Celeron Dual Core - (4 GB/64 G...   ₹13,99  44% off
# 11  Primebook 4G Android Based MediaTek MT8788 - (...   ₹13,99  44% off
# ...

# %%
laptop.to_csv("C:/Users/HP/Documents/nm/r.csv")

# %%
d=pandas.read_csv("C:/Users/HP/Documents/nm/r.csv")

# %%
d
# Out:
#     Unnamed: 0                                             laptop    price  \
# 0            0  HP Celeron Dual Core - (4 GB/128 GB EMMC Stora...   ₹18,99
# 1            1  HP Chromebook x360 Intel Celeron Quad Core - (...   ₹18,99
# 2            2  ASUS Vivobook 15 Core i3 11th Gen - (8 GB/512 ...   ₹37,99
# 3            3  ASUS Vivobook 15 Core i5 11th Gen - (8 GB/512 ...   ₹47,99
# 4            4  Lenovo IdeaPad Slim 3 Intel Core i3 11th Gen -...   ₹38,19
# 5            5  ASUS Vivobook Go 15 Celeron Dual Core - (4 GB/...   ₹25,99
# 6            6  HP 15s (2023) Intel Core i5 11th Gen - (16 GB/...   ₹55,99
# 7            7  HP Chromebook MediaTek Kompanio 500 - (4 GB/64...   ₹19,99
# 8            8  HP 15s (2023) Intel Core i3 12th Gen - (8 GB/5...   ₹42,99
# 9            9  realme Book (Slim) Core i3 11th Gen - (8 GB/25...  ₹36,999
# 10          10  ASUS Chromebook Celeron Dual Core - (4 GB/64 G...   ₹13,99
# ...
